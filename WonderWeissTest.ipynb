# %%
#Link Below was a great help when developing
#https://colab.research.google.com/github/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/Train_YOLO_Models.ipynb#scrollTo=ZfQBSwDdWoWp
import numpy as np
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt
import sys

# %%
img = cv2.imread("TestImage2.jpg")
plt.imshow(img)

# %%
model = YOLO("wonderweiss_model.pt")
detect = model(img,conf=.99)
# Out:
# 0: 448x640 7 English Ivys, 320.4ms
# Speed: 99.0ms preprocess, 320.4ms inference, 16.8ms postprocess per image at shape (1, 3, 448, 640)

# %%
#Test on image
for d in detect:
    d.show()

# %%
#For this block, WonderWeiss (The Model) seems to be really obesessed with the yellow shed
#even after putting the confendence score to above 40
#I may or may not have lobotimized him :o
capture = cv2.VideoCapture("VideoTestFinalQuick.mp4")

while capture.isOpened():
    ret, frame = capture.read()

    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break

    detectVideo = model(frame,conf=0.5)

    visual_frame = detectVideo[0].plot()

    cv2.imshow("video", visual_frame)

    if cv2.waitKey(1) == ord('q'):
        break

capture.release()
cv2.destroyAllWindows()
##detectVideo = model.predict(source="TestVideo.mp4", stream=True)

#for d in detectVideo:
    #boxes = d.boxes  # Boxes object for bbox outputs
    #masks = d.masks  # Masks object for segment masks outputs
    #probs = d.probs  # Class probabilities for classification outputs
    #d.show()
# Out:
# 0: 480x640 7 English Ivys, 432.4ms
# Speed: 17.6ms preprocess, 432.4ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 English Ivys, 184.1ms
# Speed: 2.6ms preprocess, 184.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 English Ivys, 161.0ms
# Speed: 1.4ms preprocess, 161.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 English Ivys, 159.7ms
# Speed: 2.0ms preprocess, 159.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 English Ivys, 149.4ms
# Speed: 2.9ms preprocess, 149.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 11 English Ivys, 148.9ms
# Speed: 1.3ms preprocess, 148.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 10 English Ivys, 155.0ms
# Speed: 1.3ms preprocess, 155.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
capture = cv2.VideoCapture(0);

while capture.isOpened():
    ret, frame = capture.read()

    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break

    detectVideo = model(frame,conf=0.5)

    visual_frame = detectVideo[0].plot()
    #visual_frame = cv2.putText(frame,"test", (40,40),  cv2.FONT_ITALIC, 1, (255, 0, 0), 2)
    cv2.imshow("video", visual_frame)
    cv2.putText(frame,"test", (40,40),  cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    if cv2.waitKey(1) == ord('q'):
        break

capture.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 3 English Ivys, 258.0ms
# Speed: 2.8ms preprocess, 258.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 168.7ms
# Speed: 1.9ms preprocess, 168.7ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 146.5ms
# Speed: 1.8ms preprocess, 146.5ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 149.0ms
# Speed: 1.4ms preprocess, 149.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 143.8ms
# Speed: 1.5ms preprocess, 143.8ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 138.2ms
# Speed: 1.4ms preprocess, 138.2ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 144.0ms
# Speed: 1.2ms preprocess, 144.0ms inference, 0.3ms postprocess per image at shape (1, 3, 480, 640)
#
# ...
